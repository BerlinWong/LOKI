# %%
import numpy as np

points = np.array(
    [9.1900,
     23.9000,
     16.0600,
     2.6700,
     5.1500,
     8.1200,
     3.8800,
     4.3000,
     3.2800,
     9.3300,
     3.9800,
     9.4500,
     3.2600,
     4.4900,
     7.1200,
     10.4700,
     5.6800,
     12.7300,
     26.6400,
     7.3200,
     5.1500,
     40.2500,
     11.1700,
     3.6900,
     4.8600,
     7.2200,
     13.3000,
     5.5400,
     5.3600,
     4.7900,
     12.7600,
     10.7200,
     7.1600,
     10.9200,
     5.8900,
     4.6700,
     18.1000,
     29.1000,
     9.6000,
     4.0300,
     5.2000,
     6.2800,
     5.8400,
     3.9300,
     4.6700,
     16.8900,
     19.5600,
     7.5900,
     4.7100,
     4.1700,
     5.9700,
     7.8100,
     2.9800,
     5.0100,
     7.6300,
     4.5900,
     9.0100,
     5.6400,
     2.5100,
     14.8200,
     10.2100,
     5.2200,
     3.5700,
     7.9800,
     3.4700,
     5.1800,
     4.1200,
     4.0400,
     5.4200,
     36.4400,
     7.5600,
     8.8400,
     12.1900,
     6.3400,
     24.4000,
     3.8800,
     3.7800,
     11.1800,
     5.4600,
     6.0500,
     12.1800,
     4.4700,
     3.5300,
     4.0700,
     4.3400,
     4.0400,
     1.8700,
     4.4300,
     2.9400,
     39.5500,
     3.2200,
     5.1900,
     2.4800,
     8.3000,
     4.8700,
     5.5800,
     5.2700,
     9.2700,
     7.5500,
     15.5000])
